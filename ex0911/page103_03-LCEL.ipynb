# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_core.prompts import PromptTemplate

template = "{country}의 수도는 어디인가요?" # template 정의

prompt_template = PromptTemplate.from_template(template)
prompt_template
# Out:
# PromptTemplate(input_variables=['country'], input_types={}, partial_variables={}, template='{country}의 수도는 어디인가요?')

# %%
from langchain_openai import ChatOpenAI

prompt = PromptTemplate.from_template("{topic}에 대해 쉽게 설명해주세요.")

model = ChatOpenAI()

chain = prompt | model

input = {"topic": "인공지능 모델의 학습 원리"}
chain.invoke(input)
# Out:
# AIMessage(content='인공지능 모델의 학습 원리는 주어진 데이터를 이용하여 패턴이나 규칙을 찾아내는 과정입니다. 이 모델은 입력 데이터를 받아들이고, 이 데이터에서 패턴을 학습하여 출력을 생성하게 됩니다.\n\n일반적으로, 인공지능 모델의 학습은 크게 입력층, 은닉층, 출력층으로 구성됩니다. 입력층에서는 데이터가 모델에 입력되고, 은닉층에서는 입력 데이터의 특징이 추출되어 출력층으로 전달됩니다. 출력층에서는 모델이 예측하고자 하는 값을 출력하게 됩니다.\n\n모델의 학습 과정은 주어진 데이터를 이용하여 가중치와 편향을 조정하면서 오차를 최소화 하는 과정을 수행하게 됩니다. 이렇게 학습된 모델은 새로운 데이터에 대해 예측을 수행할 수 있게 됩니다.\n\n따라서, 인공지능 모델의 학습 원리는 입력 데이터를 이용하여 패턴을 학습하고, 이를 바탕으로 새로운 데이터에 대해 예측을 수행하는 과정을 의미합니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 359, 'prompt_tokens': 33, 'total_tokens': 392, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-EMqcRpstuFCapFRrGVMPCdv5Ov2N3', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a08f84-0cee-7232-9fb0-0d3000add045-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 33, 'output_tokens': 359, 'total_tokens': 392, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
from langchain_teddynote.messages import stream_response
answer = chain.stream(input)
stream_response(answer)
# Out:
# 인공지능 모델의 학습은 데이터를 활용하여 모델이 패턴이나 규칙을 스스로 학습하도록 하는 과정입니다. 먼저 모델은 입력 데이터와 그에 대한 정답 레이블을 활용하여 학습을 시작합니다. 이후 모델은 입력 데이터를 분석하여 예측을 하고, 정답과 비교하여 오차를 계산합니다. 이 오차를 최소화하기 위해 모델은 파라미터를 업데이트하여 더 정확한 예측을 할 수 있도록 학습을 진행합니다. 이 과정을 반복하여 모델이 최적의 예측을 할 수 있도록 하는 것이 인공지능 모델의 학습 원리입니다.

# %%
from langchain_openai import ChatOpenAI

prompt = PromptTemplate.from_template("{topic}에 대해 쉽게 {how} 설명해주세요.")

model = ChatOpenAI()
print(f"{type(model)=}")

chain = prompt | model
print(f"{type(chain)=}")
# Out:
# type(model)=<class 'langchain_openai.chat_models.base.ChatOpenAI'>
# type(chain)=<class 'langchain_core.runnables.base.RunnableSequence'>

# %%
input = {"topic": "인공지능 모델의 학습 원리", "how": "5살 아이가 설명하는 것 처럼"}
chain.invoke(input)
# Out:
# AIMessage(content='인공지능 모델은 마치 뇌처럼 생각할 수 있는 컴퓨터야. 이 모델은 데이터를 받아서 공부하고, 그 데이터로부터 패턴을 찾아내서 문제를 해결해. 그래서 계속 학습을 하면서 점점 똑똑해지고, 우리가 할 수 없는 복잡한 일도 할 수 있게 돼. 이렇게 인공지능 모델은 데이터를 통해 배우고, 그것을 이용해서 다양한 일을 수행할 수 있는거야!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 160, 'prompt_tokens': 47, 'total_tokens': 207, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-EMqiV5TtxhDq8qblMmPLSVb0PqMHM', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a08f89-c8b4-7920-8294-4e4118414cc5-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 47, 'output_tokens': 160, 'total_tokens': 207, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
from langchain_openai import ChatOpenAI

prompt = PromptTemplate.from_template("{topic}에 대해 쉽게 설명해주세요.")

model = ChatOpenAI()

input = {"topic": "인공지능 모델의 학습 원리"}

# %%
from langchain_core.output_parsers import StrOutputParser

output_parser = StrOutputParser()

# %%
chain = prompt | model | output_parser

# %%
input = {"topic": "인공지능 모델의 학습 원리"}
chain.invoke(input)
# Out:
# '인공지능 모델의 학습 원리는 데이터를 사용하여 패턴을 학습하는 것입니다. 모델은 입력 데이터를 받아들이고, 해당 데이터에 대한 패턴을 찾아내어 결과를 출력합니다. 이 과정은 머신 러닝 알고리즘을 사용하여 이루어지며, 이 알고리즘은 데이터와 결과 사이의 관계를 학습하여 모델을 훈련시킵니다.\n\n모델은 초기에는 랜덤한 값을 가지고 있지만, 학습이 진행됨에 따라 데이터를 통해 점차적으로 최적의 가중치와 편향을 찾아가게 됩니다. 학습은 주어진 데이터셋을 사용하여 반복적으로 훈련시키는 과정을 거치며, 모델이 예측한 결과와 실제 결과 간의 오차를 최소화하는 방향으로 최적화됩니다.\n\n이렇게 학습된 모델은 새로운 데이터를 입력받으면 이전에 학습한 패턴을 기반으로 결과를 예측할 수 있게 됩니다. 이러한 방식으로 인공지능 모델은 데이터를 기반으로 예측, 분류, 혹은 판단하는 작업을 수행할 수 있습니다.'

# %%
template = """
당신은 200년차 영어 선생님입니다.
주어진 상황에 맞는 영어 회화를 작성해 주세요.
양식은 [FORMAT]을 참고하여 작성해 주세요.

#상황:
{question}

#FORMAT:
- 영어 회화:
- 한글 해석:
"""

# %%
prompt = PromptTemplate.from_template(template)

model = ChatOpenAI(model_name="gpt-4-turbo")

output_parser = StrOutputParser()

chain = prompt | model | output_parser

# %%
print(chain.invoke({"question": "음식을 주문하는 상황"}))
# Out:
# - 영어 회화:
#   A: "Hi, I'd like to order a Margherita pizza and a Caesar salad, please."
#   B: "Sure! Would you like any drinks with your order?"
#   A: "Yes, can I get two glasses of lemonade as well?"
#   B: "Absolutely, your total comes to $24.50. It'll be ready in about 15 minutes. Is this for dine-in or carry-out?"
#   A: "Carry-out, please."
#   B: "Great! Your order will be ready soon. Thank you!"
#
# - 한글 해석:
#   A: "안녕하세요, 마르게리타 피자 하나와 시저 샐러드 주문하겠습니다."
#   B: "네! 음료도 주문하시겠어요?"
#   A: "네, 레모네이드 두 잔도 주세요."
#   B: "알겠습니다, 총 금액은 $24.50이며, 약 15분 후에 준비됩니다. 매장에서 드시나요, 아니면 테이크아웃 하시나요?"
#   A: "테이크아웃으로 해주세요."
#   B: "좋습니다! 곧 주문하신 음식 준비해 드리겠습니다. 감사합니다!"

# %%
# 프롬프트 템플릿을 이용하여 프롬프트를 생성
prompt = PromptTemplate.from_template(template)

# ChatOpenAI 모델을 초기화
model = ChatOpenAI(model_name="gpt-4-turbo")

# 문자열 출력 파서를 초기화
output_parser = StrOutputParser()

chain = prompt | model | output_parser

# %%
print(chain.invoke({"question": "식당에 가서 음식을 주문하고 싶어요"}))
# Out:
# - 영어 회화:
#   Person A: "Hi, may I have a table for two, please?"
#   Person B: "Of course! Right this way. Here's the menu."
#   Person A: "Thank you. We'll need a few minutes to look over the menu."
#   Person B: "Take your time. Let me know when you're ready to order."
#   Person A: "Can you recommend anything special from the menu?"
#   Person B: "Certainly! Our chef's special today is the grilled salmon with lemon butter sauce. It's very popular."
#   Person A: "That sounds delicious. We'll have two of those, please."
#   Person B: "Great choice! Would you like anything to drink?"
#   Person A: "Could we have two glasses of white wine, please?"
#   Person B: "Absolutely. I'll bring your drinks right away and your meal will be ready shortly."
#
# - 한글 해석:
#   인물 A: "안녕하세요, 두 명이서 사용할 자리 있나요?"
#   인물 B: "물론이죠! 이쪽으로 오세요. 메뉴판 여기 있습니다."
#   인물 A: "감사합니다. 메뉴를 좀 볼 시간이 필요할 것 같아요."
#   인물 B: "천천히 보세요. 주문할 준비가 되면 알려주세요."
#   인물 A: "메뉴에서 특별히 추천하실 만한 게 있나요?"
#   인물 B: "물론입니다! 오늘의 셰프 특선은 레몬 버터 소스를 곁들인 구운 연어입니다. 많은 분들이 좋아하세요."
#   인물 A: "정말 맛있어 보입니다. 그걸로 두 개 주세요."
#   인물 B: "좋은 선택이세요! 음료는 무엇으로 드릴까요?"
#   인물 A: "화이트 와인 두 잔 주세요."
#   인물 B: "알겠습니다. 음료는 곧 가져다 드리겠습니다. 식사는 조금만 기다리시면 준비됩니다."

# %%
from langchain_teddynote.messages import stream_response

answer = chain.stream({"question": "미국에서 피자 주문"})
stream_response(answer)
# Out:
# - 영어 회화:
#   A: "Hi, I'd like to order a pizza for delivery, please."
#   B: "Sure! What size are you looking for?"
#   A: "A large one, please. Could I have half pepperoni and half vegetable?"
#   B: "Absolutely! Anything else you'd like to add?"
#   A: "Yes, can I have extra cheese on that, and also an order of garlic bread?"
#   B: "Of course! Can I have your address and phone number for the delivery?"
#   A: "Sure, it's 456 Maple Avenue, and my phone number is 555-1234."
#   B: "Great! Your total comes to $24.95. We'll have it delivered to you in about 45 minutes."
#   A: "Perfect, thank you!"
#
# - 한글 해석:
#   A: "안녕하세요, 배달로 피자 하나 주문하고 싶습니다."
#   B: "네! 어떤 사이즈를 원하시나요?"
#   A: "큰 걸로 하나요. 페퍼로니와 야채를 각각 절반씩 올려주세요."
#   B: "물론입니다! 추가로 더 필요한 것이 있으신가요?"
#   A: "네, 그리고 치즈를 추가해 주시고, 마늘빵도 하나 주문할게요."
#   B: "알겠습니다! 배달 주소와 전화번호를 알려주시겠어요?"
#   A: "네, 456 Maple Avenue이고 전화번호는 555-1234입니다."
#   B: "좋습니다! 전체 금액은 $24.95입니다. 약 45분 후에 배달될 예정입니다."
#   A: "완벽합니다, 감사합니다!"
