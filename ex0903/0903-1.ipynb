# %%
x=5
y="John"
print(x)
print(type(x))
# Out:
# 5
# <class 'int'>

# %%
print(type(type(1)))
# Out:
# <class 'type'>

# %%
def myfunc():
  global x
  x="fantastic"

myfunc()

print("Python is " + x)
# Out:
# Python is fantastic

# %%
a=str(1)
print(a)

'''
str="Hello, World!"
print(len(a))

for x in str:
  print(x)
'''
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1282/1677972775.py in <cell line: 0>()
# ----> 1 a=str(1)
#       2 print(a)
#       3
#       4 '''
#       5 str="Hello, World!"
#
# TypeError: 'str' object is not callable
