# %%
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

p1 = Person("홍길동", 16)
p2 = Person("벤자민", 22)
p3 = Person("세종대왕", 30)

# %%
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def greet(self):
    print("Hello, my name is " + self.name)

  def display_info(self):
    print(f"이름: {self.name}, 나이: {self.age}")

p1 = Person("Emile Jong", 25)
p1.greet()
p1.display_info()

a=p1.display_info
a()
# Out:
# Hello, my name is Emile Jong
# 이름: Emile Jong, 나이: 25
# 이름: Emile Jong, 나이: 25

# %%
print(str(1))
str=1
print(str)
print(str(1))
