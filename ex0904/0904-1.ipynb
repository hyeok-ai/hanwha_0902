# %%
age=26
txt=f"I'm {age} years old....."
print(txt)
# Out:
# I'm 26 years old.....

# %%
price = 59
txt = f"The price is {price:.2f} dollars"
print(txt)
# Out:
# The price is 59.00 dollars

# %%
txt = "banana"
x = txt.center(20)
print(txt.find("an"))
# Out:
# 1

# %%
print(x)
# Out:
#        banana

# %%
thisdict = {
    "brand": "Ford",
    "model": "Mustang",
    "year": 1964
}
print(type(thisdict))
# Out:
# <class 'dict'>
