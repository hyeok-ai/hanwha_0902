# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

model = ChatOpenAI()
prompt = PromptTemplate.from_template("{topic}에 대하여 3문장으로 설명해줘.")

chain = prompt | model | StrOutputParser()

# %%
chain.batch([{"topic": "ChatGPT"}, {"topic": "Instagram"}])
# Out:
# ['ChatGPT는 자연어 처리 기술을 기반으로 한 대화형 AI 모델로, 사용자와 자연스러운 대화를 통해 다양한 주제에 대해 응답합니다. ChatGPT는 질문에 대한 빠른 답변과 다양한 정보를 제공하여 사용자들에게 유용한 정보를 제공합니다. 또한, 일상적인 대화나 문제 해결을 위해 다양한 기능을 제공하여 사용자의 요구에 맞는 답변을 제공합니다.',
#  'Instagram은 사진이나 동영상을 공유하고 다른 사용자들과 소통할 수 있는 소셜 미디어 플랫폼이다. 사용자들은 팔로우, 좋아요, 댓글 등을 통해 서로의 활동을 공유하고 소통할 수 있다. 또한 인스타그램 스토리 기능을 활용하여 임시적인 콘텐츠를 올릴 수도 있다.']

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
model = ChatOpenAI()
prompt = PromptTemplate.from_template("{topic}에 대하여 3문장으로 설명해줘.")
chain = prompt | model | StrOutputParser()

# %%
chain
# Out:
# PromptTemplate(input_variables=['topic'], input_types={}, partial_variables={}, template='{topic}에 대하여 3문장으로 설명해줘.')
# | ChatOpenAI(metadata={'lc_versions': {'langchain-core': '1.6.3', 'langchain': '1.4.0', 'langchain-openai': '1.6.2'}}, profile={'name': 'GPT-3.5-turbo', 'status': 'deprecated', 'release_date': '2023-03-01', 'last_updated': '2023-11-06', 'open_weights': False, 'max_input_tokens': 16385, 'max_output_tokens': 4096, 'text_inputs': True, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': False, 'structured_output': False, 'attachment': False, 'temperature': True, 'image_url_inputs': False, 'pdf_inputs': False, 'pdf_tool_message': False, 'image_tool_message': False, 'tool_choice': True, 'tool_call_streaming': True}, client=<openai.resources.chat.completions.completions.Completions object at 0x000001B4CD710260>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x000001B4CD7D8AD0>, root_client=<openai.OpenAI object at 0x000001B4CD837D10>, root_async_client=<openai.AsyncOpenAI object at 0x000001B4CD711160>, model_kwargs={}, openai_api_key=SecretStr('**********'), stream_usage=True, stream_chunk_timeout=120.0)
# | StrOutputParser()

# %%
chain.batch([{"topic": "ChatGPT"}, {"topic":"Instagram"}])
# Out:
# ['ChatGPT는 인공지능 기술을 활용하여 자연스럽고 유창한 대화를 제공하는 챗봇 서비스이다. 소셜미디어, 고객지원, 교육 등 다양한 분야에서 활용되고 있으며, 사용자의 질문에 정확하고 신속하게 답변을 제공한다. ChatGPT는 계속 발전해 가며 사용자와 자연스럽게 상호작용하는 능력을 향상시키고 있다.',
#  'Instagram은 소셜 미디어 플랫폼으로, 사용자들이 사진과 동영상을 공유하며 소통할 수 있는 서비스이다. 다양한 필터와 효과를 통해 사진을 보다 멋지게 편집할 수 있고, 해시태그를 활용하여 관심사에 맞는 콘텐츠를 찾을 수 있다. 또한 스토리, 라이브 방송, IGTV 등 다양한 기능을 활용하여 더 다채로운 콘텐츠를 즐길 수 있다.']

# %%
chain.batch(
    [
        {"topic": "ChatGPT"},
        {"topic": "Instagram"},
        {"topic": "멀티모달"},
        {"topic": "프로그래밍"},
        {"topic": "머신러닝"},
    ],
    config={"max_concurrency": 3},
)
# Out:
# ['ChatGPT는 인공지능 챗봇으로 자연어 처리 기술을 사용해 대화를 주고받을 수 있게 도와줍니다. 사용자의 질문에 답변을 제공하고 채팅 상대로서 역할을 해주며 다양한 주제에 대해 대화할 수 있습니다. 실시간으로 학습하여 더 나은 응답을 제공하며 맞춤형 대화를 가능하게 합니다.',
#  '인스타그램은 사진이나 동영상을 공유하고 다른 사용자들과 소통하는 소셜 미디어 플랫폼이다. 라이브 방송, 이야기, 피드와 같은 다양한 기능을 통해 사용자들은 일상을 공유하고 소통할 수 있다. 해시태그를 통해 관심사나 주제별로 다양한 콘텐츠를 탐색할 수 있다.',
#  '멀티모달은 여러 가지 형태의 다양한 미디어를 활용하여 정보를 전달하고 상호작용하는 방식을 말합니다. 예를 들어 텍스트, 그래픽, 음성, 동영상 등 다양한 매체를 조합하여 보다 풍부한 사용자 경험을 제공합니다. 멀티모달은 사용자가 정보를 보다 쉽게 이해하고 기억할 수 있도록 돕는 동시에, 개인의 선호에 맞는 다양한 경로로 정보에 접근할 수 있게 합니다.',
#  '프로그래밍은 컴퓨터에게 실행할 일련의 명령을 작성하는 과정이다.\n컴퓨터언어를 사용하여 프로그램을 작성하고 실행함으로써 다양한 작업을 자동화할 수 있다.\n코드를 효율적으로 작성하여 원하는 결과를 얻기 위해 논리적 사고와 문제해결능력이 필요하다.',
#  '머신러닝은 컴퓨터 시스템에게 데이터로부터 패턴을 학습하고 예측하는 능력을 부여하기 위한 분야이다. 주어진 데이터를 분석하여 통계적 모델을 만들고 이를 사용하여 미래의 결과를 예측한다. 머신러닝은 인공 지능의 한 분야로써 다양한 응용 분야에서 활용되고 있다.']

# %%
async for token in chain.astream({"topic": "YouTube"}):
    print(token, end="", flush=True)
# Out:
# YouTube는 구글이 소유하고 있는 동영상 공유 플랫폼으로, 사용자들이 영상을 업로드하고 시청할 수 있는 서비스이다. 다양한 주제의 동영상 콘텐츠를 제공하며, 유저들은 댓글이나 구독을 통해 소통할 수 있다. 유명한 유튜버들이 활동하며, 시청자들은 그들의 채널을 구독하여 최신 업데이트를 받을 수 있다.

# %%
my_process = chain.ainvoke({"topic": "NVDA"})

# %%
await my_process
# Out:
# 'NVDA는 엔비디아 주식을 나타내는 주식 코드이며, 엔비디아는 그래픽 처리 유닛(GPU)을 제조하는 기업이다. NVDA 주가는 기술 시장의 동향과 회사의 실적에 따라 변동한다.'
