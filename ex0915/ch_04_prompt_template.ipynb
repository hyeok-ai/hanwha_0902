# %%
# !pip install langchain_teddynote
# Out:
# Requirement already satisfied: langchain_teddynote in .\.venv\Lib\site-packages (0.5.4)
# Requirement already satisfied: anthropic>=0.64.0 in .\.venv\Lib\site-packages (from langchain_teddynote) (1.5.0)
# Requirement already satisfied: deepl>=1.22.0 in .\.venv\Lib\site-packages (from langchain_teddynote) (1.32.0)
# Requirement already satisfied: feedparser>=6.0.11 in .\.venv\Lib\site-packages (from langchain_teddynote) (6.0.14)
# Requirement already satisfied: kiwipiepy>=0.21.0 in .\.venv\Lib\site-packages (from langchain_teddynote) (0.23.2)
# Requirement already satisfied: konlpy>=0.6.0 in .\.venv\Lib\site-packages (from langchain_teddynote) (0.6.0)
# Requirement already satisfied: langchain-openai>=0.3.30 in .\.venv\Lib\site-packages (from langchain_teddynote) (1.6.2)
# Requirement already satisfied: langchain>=0.3.27 in .\.venv\Lib\site-packages (from langchain_teddynote) (1.4.0)
# Requirement already satisfied: langgraph>=0.6.5 in .\.venv\Lib\site-packages (from langchain_teddynote) (1.2.11)
# Requirement already satisfied: olefile>=0.47 in .\.venv\Lib\site-packages (from langchain_teddynote) (0.47)
# Requirement already satisfied: openai>=1.99.9 in .\.venv\Lib\site-packages (from langchain_teddynote) (3.14.0)
# Requirement already satisfied: pandas>=2.3.1 in .\.venv\Lib\site-packages (from langchain_teddynote) (3.0.5)
# Requirement already satisfied: pdf2image>=1.17.0 in .\.venv\Lib\site-packages (from langchain_teddynote) (1.17.0)
# Requirement already satisfied: pinecone-client>=6.0.0 in .\.venv\Lib\site-packages (from langchain_teddynote) (6.0.0)
# Requirement already satisfied: pinecone-text>=0.11.0 in .\.venv\Lib\site-packages (from langchain_teddynote) (0.11.0)
# Requirement already satisfied: python-dotenv>=1.1.1 in .\.venv\Lib\site-packages (from langchain_teddynote) (1.2.3)
# Requirement already satisfied: rank-bm25>=0.2.2 in .\.venv\Lib\site-packages (from langchain_teddynote) (0.2.2)
# Requirement already satisfied: tavily-python>=0.7.10 in .\.venv\Lib\site-packages (from langchain_teddynote) (0.8.3)
# Requirement already satisfied: twine>=6.1.0 in .\.venv\Lib\site-packages (from langchain_teddynote) (7.0.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in .\.venv\Lib\site-packages (from anthropic>=0.64.0->langchain_teddynote) (4.15.1)
# Requirement already satisfied: docstring-parser<1,>=0.15 in .\.venv\Lib\site-packages (from anthropic>=0.64.0->langchain_teddynote) (0.18.0)
# Requirement already satisfied: httpx2<3,>=2.0.0 in .\.venv\Lib\site-packages (from anthropic>=0.64.0->langchain_teddynote) (2.13.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in .\.venv\Lib\site-packages (from anthropic>=0.64.0->langchain_teddynote) (0.17.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in .\.venv\Lib\site-packages (from anthropic>=0.64.0->langchain_teddynote) (2.13.5)
# Requirement already satisfied: sniffio<2,>=1 in .\.venv\Lib\site-packages (from anthropic>=0.64.0->langchain_teddynote) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in .\.venv\Lib\site-packages (from anthropic>=0.64.0->langchain_teddynote) (4.16.0)
# Requirement already satisfied: idna>=2.8 in .\.venv\Lib\site-packages (from anyio<5,>=3.5.0->anthropic>=0.64.0->langchain_teddynote) (3.19)
# Requirement already satisfied: httpcore2==2.13.0 in .\.venv\Lib\site-packages (from httpx2<3,>=2.0.0->anthropic>=0.64.0->langchain_teddynote) (2.13.0)
# Requirement already satisfied: truststore>=0.10 in .\.venv\Lib\site-packages (from httpx2<3,>=2.0.0->anthropic>=0.64.0->langchain_teddynote) (0.10.4)
# Requirement already satisfied: h11>=0.16 in .\.venv\Lib\site-packages (from httpcore2==2.13.0->httpx2<3,>=2.0.0->anthropic>=0.64.0->langchain_teddynote) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in .\.venv\Lib\site-packages (from pydantic<3,>=1.9.0->anthropic>=0.64.0->langchain_teddynote) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in .\.venv\Lib\site-packages (from pydantic<3,>=1.9.0->anthropic>=0.64.0->langchain_teddynote) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in .\.venv\Lib\site-packages (from pydantic<3,>=1.9.0->anthropic>=0.64.0->langchain_teddynote) (0.4.4)
# Requirement already satisfied: requests>=2.32.5 in .\.venv\Lib\site-packages (from deepl>=1.22.0->langchain_teddynote) (2.34.2)
# Requirement already satisfied: feedparser-sgmllib<3,>=2 in .\.venv\Lib\site-packages (from feedparser>=6.0.11->langchain_teddynote) (2.1.0)
# Requirement already satisfied: kiwipiepy_model<0.24,>=0.23 in .\.venv\Lib\site-packages (from kiwipiepy>=0.21.0->langchain_teddynote) (0.23.0)
# Requirement already satisfied: numpy in .\.venv\Lib\site-packages (from kiwipiepy>=0.21.0->langchain_teddynote) (2.5.3)
# Requirement already satisfied: tqdm in .\.venv\Lib\site-packages (from kiwipiepy>=0.21.0->langchain_teddynote) (4.70.1)
# Requirement already satisfied: JPype1>=0.7.0 in .\.venv\Lib\site-packages (from konlpy>=0.6.0->langchain_teddynote) (1.7.1)
# Requirement already satisfied: lxml>=4.1.0 in .\.venv\Lib\site-packages (from konlpy>=0.6.0->langchain_teddynote) (6.1.3)
# Requirement already satisfied: packaging in .\.venv\Lib\site-packages (from JPype1>=0.7.0->konlpy>=0.6.0->langchain_teddynote) (26.3)
# Requirement already satisfied: langchain-core<2.0.0,>=1.6.0 in .\.venv\Lib\site-packages (from langchain>=0.3.27->langchain_teddynote) (1.6.3)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in .\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain>=0.3.27->langchain_teddynote) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in .\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain>=0.3.27->langchain_teddynote) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in .\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain>=0.3.27->langchain_teddynote) (0.0.19)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in .\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain>=0.3.27->langchain_teddynote) (0.12.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in .\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain>=0.3.27->langchain_teddynote) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in .\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain>=0.3.27->langchain_teddynote) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in .\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain>=0.3.27->langchain_teddynote) (0.17.1)
# Requirement already satisfied: certifi in .\.venv\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain>=0.3.27->langchain_teddynote) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in .\.venv\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain>=0.3.27->langchain_teddynote) (1.0.9)
# Requirement already satisfied: jsonpointer>=1.9 in .\.venv\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.6.0->langchain>=0.3.27->langchain_teddynote) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in .\.venv\Lib\site-packages (from langgraph>=0.6.5->langchain_teddynote) (4.2.0)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in .\.venv\Lib\site-packages (from langgraph>=0.6.5->langchain_teddynote) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in .\.venv\Lib\site-packages (from langgraph>=0.6.5->langchain_teddynote) (0.4.4)
# Requirement already satisfied: xxhash>=3.5.0 in .\.venv\Lib\site-packages (from langgraph>=0.6.5->langchain_teddynote) (4.0.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in .\.venv\Lib\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph>=0.6.5->langchain_teddynote) (1.12.2)
# Requirement already satisfied: orjson>=3.11.5 in .\.venv\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph>=0.6.5->langchain_teddynote) (3.12.0)
# Requirement already satisfied: websockets<17,>=14 in .\.venv\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph>=0.6.5->langchain_teddynote) (16.1.1)
# Requirement already satisfied: distro>=1.7.0 in .\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain>=0.3.27->langchain_teddynote) (1.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in .\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain>=0.3.27->langchain_teddynote) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in .\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain>=0.3.27->langchain_teddynote) (0.25.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in .\.venv\Lib\site-packages (from langchain-openai>=0.3.30->langchain_teddynote) (0.14.0)
# Requirement already satisfied: regex in .\.venv\Lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai>=0.3.30->langchain_teddynote) (2026.9.10)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\.venv\Lib\site-packages (from pandas>=2.3.1->langchain_teddynote) (2.9.0.post0)
# Requirement already satisfied: tzdata in .\.venv\Lib\site-packages (from pandas>=2.3.1->langchain_teddynote) (2026.4)
# Requirement already satisfied: pillow in .\.venv\Lib\site-packages (from pdf2image>=1.17.0->langchain_teddynote) (12.3.0)
# Requirement already satisfied: pinecone-plugin-interface<0.0.8,>=0.0.7 in .\.venv\Lib\site-packages (from pinecone-client>=6.0.0->langchain_teddynote) (0.0.7)
# Requirement already satisfied: urllib3>=1.26.5 in .\.venv\Lib\site-packages (from pinecone-client>=6.0.0->langchain_teddynote) (2.7.0)
# Requirement already satisfied: mmh3<5.0.0,>=4.1.0 in .\.venv\Lib\site-packages (from pinecone-text>=0.11.0->langchain_teddynote) (4.1.0)
# Requirement already satisfied: nltk<4.0.0,>=3.9.1 in .\.venv\Lib\site-packages (from pinecone-text>=0.11.0->langchain_teddynote) (3.10.3)
# Requirement already satisfied: types-requests<3.0.0,>=2.25.0 in .\.venv\Lib\site-packages (from pinecone-text>=0.11.0->langchain_teddynote) (2.33.0.20260906)
# Requirement already satisfied: defusedxml in .\.venv\Lib\site-packages (from nltk<4.0.0,>=3.9.1->pinecone-text>=0.11.0->langchain_teddynote) (0.7.1)
# Requirement already satisfied: click in .\.venv\Lib\site-packages (from nltk<4.0.0,>=3.9.1->pinecone-text>=0.11.0->langchain_teddynote) (8.5.0)
# Requirement already satisfied: joblib in .\.venv\Lib\site-packages (from nltk<4.0.0,>=3.9.1->pinecone-text>=0.11.0->langchain_teddynote) (1.6.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\.venv\Lib\site-packages (from requests>=2.32.5->deepl>=1.22.0->langchain_teddynote) (3.5.1)
# Requirement already satisfied: six>=1.5 in .\.venv\Lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.3.1->langchain_teddynote) (1.17.0)
# Requirement already satisfied: readme-renderer>=35.0 in .\.venv\Lib\site-packages (from twine>=6.1.0->langchain_teddynote) (46.0)
# Requirement already satisfied: keyring>=21.2.0 in .\.venv\Lib\site-packages (from twine>=6.1.0->langchain_teddynote) (25.7.0)
# Requirement already satisfied: rfc3986>=1.4.0 in .\.venv\Lib\site-packages (from twine>=6.1.0->langchain_teddynote) (2.0.0)
# Requirement already satisfied: rich>=14.3.3 in .\.venv\Lib\site-packages (from twine>=6.1.0->langchain_teddynote) (15.0.0)
# Requirement already satisfied: id in .\.venv\Lib\site-packages (from twine>=6.1.0->langchain_teddynote) (1.6.1)
# Requirement already satisfied: pywin32-ctypes>=0.2.0 in .\.venv\Lib\site-packages (from keyring>=21.2.0->twine>=6.1.0->langchain_teddynote) (0.2.3)
# Requirement already satisfied: jaraco.classes in .\.venv\Lib\site-packages (from keyring>=21.2.0->twine>=6.1.0->langchain_teddynote) (3.4.0)
# Requirement already satisfied: jaraco.functools in .\.venv\Lib\site-packages (from keyring>=21.2.0->twine>=6.1.0->langchain_teddynote) (4.6.0)
# Requirement already satisfied: jaraco.context in .\.venv\Lib\site-packages (from keyring>=21.2.0->twine>=6.1.0->langchain_teddynote) (6.1.2)
# Requirement already satisfied: nh3>=0.2.14 in .\.venv\Lib\site-packages (from readme-renderer>=35.0->twine>=6.1.0->langchain_teddynote) (0.3.7)
# Requirement already satisfied: docutils>=0.21.2 in .\.venv\Lib\site-packages (from readme-renderer>=35.0->twine>=6.1.0->langchain_teddynote) (0.23)
# Requirement already satisfied: Pygments>=2.5.1 in .\.venv\Lib\site-packages (from readme-renderer>=35.0->twine>=6.1.0->langchain_teddynote) (2.21.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in .\.venv\Lib\site-packages (from rich>=14.3.3->twine>=6.1.0->langchain_teddynote) (4.2.0)
# Requirement already satisfied: mdurl~=0.1 in .\.venv\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=14.3.3->twine>=6.1.0->langchain_teddynote) (0.1.2)
# Requirement already satisfied: more-itertools in .\.venv\Lib\site-packages (from jaraco.classes->keyring>=21.2.0->twine>=6.1.0->langchain_teddynote) (11.1.0)
# Requirement already satisfied: cloudpickle>=3.0 in .\.venv\Lib\site-packages (from joblib->nltk<4.0.0,>=3.9.1->pinecone-text>=0.11.0->langchain_teddynote) (3.1.2)
# Requirement already satisfied: colorama in .\.venv\Lib\site-packages (from tqdm->kiwipiepy>=0.21.0->langchain_teddynote) (0.4.6)

# %%
from dotenv import load_dotenv
from langchain_teddynote import logging

load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI()

# %%
from langchain_core.prompts import PromptTemplate

template = "{country}의 수도는 어디인가요?"

prompt = PromptTemplate.from_template(template)
prompt
# Out:
# PromptTemplate(input_variables=['country'], input_types={}, partial_variables={}, template='{country}의 수도는 어디인가요?')

# %%
prompt = prompt.format(country="대한민국")
prompt
# Out:
# '대한민국의 수도는 어디인가요?'

# %%
template = "{country}의 수도는 어디인가요?"

prompt = PromptTemplate.from_template(template)

chain = prompt | llm

# %%
chain.invoke("대한민국").content
# Out:
# '대한민국의 수도는 서울입니다.'

# %%
# template 정의
template = "{country}의 수도는 어디인가요?"

# PromptTemplate 객체를 활용하여 prompt_template 생성
prompt = PromptTemplate(
    template=template,
    input_variables=["country"],
)

prompt
# Out:
# PromptTemplate(input_variables=['country'], input_types={}, partial_variables={}, template='{country}의 수도는 어디인가요?')

# %%
# prompt 생성
prompt.format(country="대한민국")
# Out:
# '대한민국의 수도는 어디인가요?'

# %%
# template 정의
template = "{country1}과 {country2}의 수도는 각각 어디인가요?"

# PromptTemplate 객체를 활용하여 prompt_template 생성
prompt = PromptTemplate(
    template=template,
    input_variables=["country1"],
    partial_variables={
        "country2": "미국"  # dictionary 형태로 partial_variables를 전달
    },
)

prompt
# Out:
# PromptTemplate(input_variables=['country1'], input_types={}, partial_variables={'country2': '미국'}, template='{country1}과 {country2}의 수도는 각각 어디인가요?')

# %%
prompt.format(country1="대한민국")
# Out:
# '대한민국과 미국의 수도는 각각 어디인가요?'

# %%
prompt_partial = prompt.partial(country2="캐나다")
prompt_partial
# Out:
# PromptTemplate(input_variables=['country1'], input_types={}, partial_variables={'country2': '캐나다'}, template='{country1}과 {country2}의 수도는 각각 어디인가요?')

# %%
prompt_partial.format(country1="대한민국")
# Out:
# '대한민국과 캐나다의 수도는 각각 어디인가요?'

# %%
chain = prompt_partial | llm
chain.invoke("대한민국").content
# Out:
# '대한민국의 수도는 서울이고, 캐나다의 수도는 오타와입니다.'

# %%
chain.invoke({"country1": "대한민국", "country2": "호주"}).content
# Out:
# '대한민국의 수도는 서울이고, 호주의 수도는 캔버라입니다.'

# %%
from datetime import datetime

# 오늘 날짜를 출력
datetime.now().strftime("%B %d")
# Out:
# 'September 15'

# %%
# 날짜를 반환하는 함수 정의
def get_today():
    return datetime.now().strftime("%B %d")

# %%
prompt = PromptTemplate(
    template="오늘의 날짜는 {today} 입니다. 오늘이 생일인 유명인 {n}명을 나열해 주세요. 생년월일을 표기해주세요.",
    input_variables=["n"],
    partial_variables={
        "today": get_today  # dictionary 형태로 partial_variables를 전달
    },
)

# %%
# n에 직접 3 값 대입
print(prompt.format(n=3))

# chain 을 생성
chain = prompt | llm

# n=3, 오늘 날짜는 get_today 호출
print(chain.invoke(3).content)

# 필요시에 get_today 호출 대신 원하는 값을 넣어서 질의 가능
print(chain.invoke({"today": "Jan 02", "n": 3}).content)
# Out:
# 오늘의 날짜는 September 15 입니다. 오늘이 생일인 유명인 3명을 나열해 주세요. 생년월일을 표기해주세요.
# 1. Prince Harry (1984년 9월 15일)
# 2. Tommy Lee Jones (1946년 9월 15일)
# 3. Agatha Christie (1890년 9월 15일)
# 1. 김태희 - 1980년 3월 29일
# 2. 로하스 - 1999년 1월 2일
# 3. 유호석(형돈) - 1979년 1월 2일

# %%
from langchain_core.prompts import load_prompt

prompt = load_prompt("prompts/fruit_color.yaml", encoding="utf-8")
prompt
# Out:
# PromptTemplate(input_variables=['fruit'], input_types={}, partial_variables={}, template='{fruit}의 색깔이 뭐야?')

# %%
prompt.format(fruit="사과")
# Out:
# '사과의 색깔이 뭐야?'

# %%
prompt2 = load_prompt("prompts/capital.yaml", encoding="utf-8")
print(prompt2.format(country="대한민국"))
# Out:
# 대한민국의 수도에 대해서 알려주세요.
# 수도의 특징을 다음의 양식에 맞게 정리해 주세요.
# 300자 내외로 작성해 주세요.
# 한글로 작성해 주세요.
# ----
# [양식]
# 1. 면적
# 2. 인구
# 3. 역사적 장소
# 4. 특산품
#
# #Answer:

# %%
from langchain_core.prompts import ChatPromptTemplate

chat_prompt = ChatPromptTemplate.from_template("{country}의 수도는 어디인가요?")
chat_prompt
# Out:
# ChatPromptTemplate(input_variables=['country'], input_types={}, partial_variables={}, messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['country'], input_types={}, partial_variables={}, template='{country}의 수도는 어디인가요?'), additional_kwargs={})])

# %%
chat_prompt.format(country="대한민국")
# Out:
# 'Human: 대한민국의 수도는 어디인가요?'

# %%
from langchain_core.prompts import ChatPromptTemplate

chat_template = ChatPromptTemplate.from_messages(
    [
        # role, message
        ("system", "당신은 친절한 AI 어시스턴트입니다. 당신의 이름은 {name} 입니다."),
        ("human", "반가워요!"),
        ("ai", "안녕하세요! 무엇을 도와드릴까요?"),
        ("human", "{user_input}"),
    ]
)

# 챗 message 를 생성합니다.
messages = chat_template.format_messages(
    name="테디", user_input="당신의 이름은 무엇입니까?"
)
messages
# Out:
# [SystemMessage(content='당신은 친절한 AI 어시스턴트입니다. 당신의 이름은 테디 입니다.', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='반가워요!', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='안녕하세요! 무엇을 도와드릴까요?', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]),
#  HumanMessage(content='당신의 이름은 무엇입니까?', additional_kwargs={}, response_metadata={})]

# %%
llm.invoke(messages).content
# Out:
# '제 이름은 테디입니다. 필요하신 도움이 있다면 언제든지 말씀해주세요.'

# %%
chain = chat_template | llm

chain.invoke({"name": "Teddy", "user_input": "당신의 이름은 무엇입니까?"}).content

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder

chat_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "당신은 요약 전문 AI 어시스턴트입니다. 당신의 임무는 주요 키워드로 대화를 요약하는 것입니다.",
        ),
        MessagesPlaceholder(variable_name="conversation"),
        ("human", "지금까지의 대화를 {word_count} 단어로 요약합니다."),
    ]
)
chat_prompt
# Out:
# ChatPromptTemplate(input_variables=['conversation', 'word_count'], input_types={'conversation': list[typing.Annotated[typing.Union[typing.Annotated[langchain_core.messages.ai.AIMessage, Tag(tag='ai')], typing.Annotated[langchain_core.messages.human.HumanMessage, Tag(tag='human')], typing.Annotated[langchain_core.messages.chat.ChatMessage, Tag(tag='chat')], typing.Annotated[langchain_core.messages.system.SystemMessage, Tag(tag='system')], typing.Annotated[langchain_core.messages.function.FunctionMessage, Tag(tag='function')], typing.Annotated[langchain_core.messages.tool.ToolMessage, Tag(tag='tool')], typing.Annotated[langchain_core.messages.ai.AIMessageChunk, Tag(tag='AIMessageChunk')], typing.Annotated[langchain_core.messages.human.HumanMessageChunk, Tag(tag='HumanMessageChunk')], typing.Annotated[langchain_core.messages.chat.ChatMessageChunk, Tag(tag='ChatMessageChunk')], typing.Annotated[langchain_core.messages.system.SystemMessageChunk, Tag(tag='SystemMessageChunk')], typing.Annotated[langchain_core.messages.function.FunctionMessageChunk, Tag(tag='FunctionMessageChunk')], typing.Annotated[langchain_core.messages.tool.ToolMessageChunk, Tag(tag='ToolMessageChunk')]], FieldInfo(annotation=NoneType, required=True, discriminator=Discriminator(discriminator=<function _get_type at 0x000001644DAD8180>, custom_error_type=None, custom_error_message=None, custom_error_context=None))]]}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='당신은 요약 전문 AI 어시스턴트입니다. 당신의 임무는 주요 키워드로 대화를 요약하는 것입니다.'), additional_kwargs={}), MessagesPlaceholder(variable_name='conversation'), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['word_count'], input_types={}, partial_variables={}, template='지금까지의 대화를 {word_count} 단어로 요약합니다.'), additional_kwargs={})])

# %%
formatted_chat_prompt = chat_prompt.format(
    word_count=5,
    conversation=[
        ("human", "안녕하세요! 저는 오늘 새로 입사한 테디 입니다. 만나서 반갑습니다."),
        ("ai", "반가워요! 앞으로 잘 부탁 드립니다."),
    ],
)

print(formatted_chat_prompt)
# Out:
# System: 당신은 요약 전문 AI 어시스턴트입니다. 당신의 임무는 주요 키워드로 대화를 요약하는 것입니다.
# Human: 안녕하세요! 저는 오늘 새로 입사한 테디 입니다. 만나서 반갑습니다.
# AI: 반가워요! 앞으로 잘 부탁 드립니다.
# Human: 지금까지의 대화를 5 단어로 요약합니다.

# %%
# chain 생성
chain = chat_prompt | llm | StrOutputParser()

# chain 실행 및 결과확인
chain.invoke(
    {
        "word_count": 1,
        "conversation": [
            (
                "human",
                "안녕하세요! 저는 오늘 새로 입사한 테디 입니다. 만나서 반갑습니다.",
            ),
            ("ai", "반가워요! 앞으로 잘 부탁 드립니다."),
        ],
    }
)
# Out:
# '만남, 환영'
