# %%
def myfunc():
  print("hello")

myfunc()
# Out:
# hello

# %%
def cel(f):
  return f+100

print(cel(77))

def f1(su):
  return su+100

def f2(su):
  return su-100

def f3(su):
  return su*100

def f4(su):
  return su/100

print( f1(5) )
print( f2(5) )
print( f3(5) )
print( f4(5) )
# Out:
# 177
# 105
# -95
# 500
# 0.05

# %%
print(list(range(5, 20, 6)))
# Out:
# [5, 11, 17]

# %%
import numpy as np

arr = np.array([1,2,3,4,5])

print(arr)

print(type(arr))
# Out:
# [1 2 3 4 5]
# <class 'numpy.ndarray'>

# %%
import pandas
mydataset = {
    'cars': ["BMW", "Volvo", "Ford"],
    'passings': [3, 7, 2]
}

myvar = pandas.DataFrame(mydataset)

print(myvar)
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2
