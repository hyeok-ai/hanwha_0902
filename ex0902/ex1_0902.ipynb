# %%
print("테스트")
# Out:
# 테스트

# %%
x="John"

# %%
y='John'

# %%
print(x,y)
# Out:
# John John

# %%
x=10

# %%
y=20
print(x+y)
# Out:
# 30

# %%
x=5

# %%
y="John"

# %%
print(x+y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3744/501100011.py in <cell line: 0>()
# ----> 1 print(x+y)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
